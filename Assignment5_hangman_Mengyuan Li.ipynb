# %%
import random
import time

# Initial Steps to invite in the game:
print("\n Hello! Welcome to Hangman game\n")
name = input("Enter your name: ")
print("Nice to meet you " + name )
time.sleep(2)
print("Game is starting...\n ")
time.sleep(3)


def main():
    global count
    global display
    global word
    global already_guessed
    global length
    global play_game
    words_to_guess = ["mother","passion","eternity","fantastic","destiny","liberty","peace","sunshine","hope","grace"
                   ,"blue"]
    word = random.choice(words_to_guess)
    length = len(word)
    count = 0
    display = '_' * length
    already_guessed = []
    play_game = ""


def play_loop():
    global play_game
    play_game = input("Do You want to play again? y = yes, n = no \n")
    while play_game not in ["y", "n","Y","N"]:
        play_game = input("Do You want to play again? y = yes, n = no \n")
    if play_game == "y":
        main()
    elif play_game == "n":
        print("Thanks For Playing! ")
        exit()

def hangman():
    global count
    global display
    global word
    global already_guessed
    global play_game
    limit = 5
    guess = input("This is the Hangman Word: " + display + " Enter your guess: \n")
    guess = guess.strip()
    if len(guess.strip()) == 0 or len(guess.strip()) >= 2 or guess <= "9":
        print("Invalid Input, Try a letter\n")
        hangman()


    elif guess in word:
        already_guessed.extend([guess])
        index = word.find(guess)
        word = word[:index] + "_" + word[index + 1:]
        display = display[:index] + guess + display[index + 1:]
        print(display + "\n")

    elif guess in already_guessed:
        print("Try another letter.\n")

    else:
        count += 1

        if count == 1:
            time.sleep(1)
            print("   ___ \n"
                  "  |      \n"
                  "  |      \n"
                  "  |      \n"
                  "  |      \n"
                  "  |      \n"
                  "  |      \n"
                  "_|_\n")
            print("Wrong guess. " + str(limit - count) + " guesses remaining\n")

        elif count == 2:
            time.sleep(1)
            print("   ___ \n"
                  "  |     | \n"
                  "  |     |\n"
                  "  |      \n"
                  "  |      \n"
                  "  |      \n"
                  "  |      \n"
                  "_|_\n")
            print("Wrong guess. " + str(limit - count) + " guesses remaining\n")

        elif count == 3:
           time.sleep(1)
           print("   ___ \n"
                 "  |     | \n"
                 "  |     |\n"
                 "  |     | \n"
                 "  |      \n"
                 "  |      \n"
                 "  |      \n"
                 "_|_\n")
           print("Wrong guess. " + str(limit - count) + " guesses remaining\n")

        elif count == 4:
            time.sleep(1)
            print("   ___ \n"
                  "  |     | \n"
                  "  |     |\n"
                  "  |     | \n"
                  "  |     O \n"
                  "  |      \n"
                  "  |      \n"
                  "_|_\n")
            print("Wrong guess. " + str(limit - count) + " last guess remaining\n")

        elif count == 5:
            time.sleep(1)
            print("   ___ \n"
                  "  |     | \n"
                  "  |     |\n"
                  "  |     | \n"
                  "  |     O \n"
                  "  |    /|\ \n"
                  "  |    / \ \n"
                  "_|_\n")
            print("Wrong guess. You are hanged!!!\n")
            print("The word was:",already_guessed,word)
            play_loop()

    if word == '_' * length:
        print("Congrats! You have guessed the word correctly!")
        play_loop()

    elif count != limit:
        hangman()


main()


hangman()
# Out:
#  Hello! Welcome to Hangman game
#
# Enter your name: Mengyuan Li
# Nice to meet you Mengyuan Li
# Game is starting...
#
# This is the Hangman Word: _______ Enter your guess:
# w
#    ___
#   |
#   |
#   |
#   |
#   |
#   |
# _|_
#
# Wrong guess. 4 guesses remaining
#
# This is the Hangman Word: _______ Enter your guess:
# l
# l______
#
# This is the Hangman Word: l______ Enter your guess:
# i
# li_____
#
# This is the Hangman Word: li_____ Enter your guess:
# b
# lib____
#
# This is the Hangman Word: lib____ Enter your guess:
# e
# libe___
#
# This is the Hangman Word: libe___ Enter your guess:
# r
# liber__
#
# This is the Hangman Word: liber__ Enter your guess:
# t
# libert_
#
# This is the Hangman Word: libert_ Enter your guess:
# y
# liberty
#
# Congrats! You have guessed the word correctly!
# Do You want to play again? y = yes, n = no
# no
# Do You want to play again? y = yes, n = no
# no
